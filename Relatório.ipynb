# %% [markdown]
# # MVP ENGENHARIA DE DADOS
#
# **Aluno:** Rodrigo de Sousa Araujo
#
# **Matrícula:** 4052025001727

# %% [markdown]
# # Contexto

# %% [markdown]
# # Objetivos de análise

# %%
# %sql
COPY INTO workspace.default.dados_compilados
  FROM '/Volumes/workspace/default/myfiles'
  fileformat = CSV
  FORMAT_OPTIONS (
    'header' = 'true',
    'inferSchema' = 'true'
  )
# Out:
# ---------------------------------------------------------------------------
# UnknownException                          Traceback (most recent call last)
# File <command-6520949098198417>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "COPY INTO workspace.default.dados_compilados\n  FROM '/Volumes/workspace/default/myfiles'\n  fileformat = CSV\n  FORMAT_OPTIONS (\n    'header' = 'true',\n    'inferSchema' = 'true'\n  )\n")
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %sql
CREATE TABLE dados_compilados2 (
  INICIAIS STRING,
  SEXO STRING,
  IDADE INT,
  ESTADO_CIVIL STRING,
  COR STRING,
  OCUPACAO STRING,
  INSTRUCAO STRING,
  DATA_FATO DATE,
  HORA_FATO STRING,
  DELITO STRING,
  ID_MUNICIPIO INT,
  MUNICIPIO_FATO STRING,
  BAIRRO STRING,
  LATITUDE FLOAT,
  LONGITUDE FLOAT,
  TERRITORIO_DE_IDENTIDADE STRING,
  ANO INT,
  TOTAL INT
);

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados2 SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name')

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados2 RENAME COLUMN IDADE TO IDADE2
ALTER TABLE workspace.default.dados_compilados2 RENAME COLUMN DATA_FATO TO DATA_FATO2

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados2 RENAME COLUMN DATA_FATO TO DATA_FATO2

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados2 RENAME COLUMN ID_MUNICIPIO TO ID_MUNICIPIO2

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados2 RENAME COLUMN ID_MUNICIPIO TO ID_MUNICIPIO2

# %%
# %sql
COPY INTO workspace.default.dados_compilados2
  FROM '/Volumes/workspace/default/myfiles'
  FILEFORMAT = CSV
  FORMAT_OPTIONS (
    'header' = 'true',
    'inferSchema' = 'true'
)

# %%
# %sql
CREATE TABLE dados_compilados3 (
  INICIAIS STRING,
  SEXO STRING,
  IDADE INT,
  ESTADO_CIVIL STRING,
  COR STRING,
  OCUPACAO STRING,
  INSTRUCAO STRING,
  DATA_FATO DATE,
  HORA_FATO STRING,
  DELITO STRING,
  ID_MUNICIPIO INT,
  MUNICIPIO_FATO STRING,
  BAIRRO STRING,
  LATITUDE FLOAT,
  LONGITUDE FLOAT,
  TERRITORIO_DE_IDENTIDADE STRING,
  ANO INT,
  TOTAL INT
);

# %%
# %sql
COPY INTO workspace.default.dados_compilados3
  FROM 
  FILEFORMAT = CSV
  FORMAT_OPTIONS (
    'header' = 'true',
    'inferSchema' = 'true'
)

# %%
# %sql
SELECT * FROM myfiles.default.`2024_mortes_violentas_estado_microdados_0` LIMIT 50

# %%
# %sql
SELECT INICIAIS,IDADE FROM myfiles.default.`2024_mortes_violentas_estado_microdados_0`WHERE IDADE < 18

# %%
# %sql
select * FROM workspace.default.dados_compilados

# %%
# %sql
SELECT * FROM myfiles.default.`2024_mortes_violentas_estado`;

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name')

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados
DROP COLUMN LATITUDE;

# %%
# %sql
ALTER TABLE workspace.default.dados_compilados
DROP COLUMN LONGITUDE;

# %%
# %sql
INSERT INTO workspace.default.dados_compilados
SELECT * FROM workspace.default.`25_mortes_violentas_estado`
UNION ALL
SELECT * FROM workspace.default.`24_mortes_violentas_estado`;

# %%
# %sql
INSERT INTO workspace.default.dados_compilados
SELECT * FROM workspace.default.`23_mortes_violentas_estado`;

# %%
# %sql
SELECT COUNT(*) AS total_linhas
FROM workspace.default.dados_compilados
WHERE ANO = 2025;

# %%
# %sql
SELECT COUNT(*) AS total_linhas
FROM workspace.default.dados_compilados;
